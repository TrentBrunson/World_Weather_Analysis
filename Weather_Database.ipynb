# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests # Import the requests library.

# Import the weather API key.
from config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(len(cities))
cities
# Out:
# 605
# ['eureka',
#  'upernavik',
#  'hasaki',
#  'ushuaia',
#  'khatanga',
#  'punta arenas',
#  'port alfred',
#  'atuona',
#  'hobart',
#  'rikitea',
#  'cape town',
#  'raudeberg',
#  'mataura',
#  'ukiah',
#  'barentsburg',
#  'bredasdorp',
#  'bilma',
#  'busselton',
#  'hilo',
#  'qaanaaq',
#  'toliary',
#  'umea',
#  'karratha',
#  'basse',
#  'pryazha',
#  'jamestown',
#  'kruisfontein',
#  'thompson',
#  'ribeira grande',
#  'lahaina',
#  'mishan',
#  'mehamn',
#  'avarua',
#  'grand river south east',
#  'fairbanks',
#  'taolanaro',
#  'nadym',
#  'palabuhanratu',
#  'kaitangata',
#  'quang ngai',
#  'vaini',
#  'touros',
#  'alice springs',
#  'namibe',
#  'adwa',
#  'sola',
#  'russell',
#  'pevek',
#  'guangyuan',
#  'barrow',
#  'carnarvon',
#  'tuktoyaktuk',
#  'ordzhonikidze',
#  'sitka',
#  'sao joao da barra',
#  'labutta',
#  'mar del plata',
#  'kapaa',
#  'lillooet',
#  'tsihombe',
#  'batagay',
#  'kuche',
#  'amqui',
#  'albany',
#  'cidreira',
#  'fortuna',
#  'namatanai',
#  'havre-saint-pierre',
#  'isangel',
#  'saskylakh',
#  'torbay',
#  'atbasar',
#  'villefranche-sur-saone',
#  'guerrero negro',
#  'rio grande',
#  'geraldton',
#  'buraydah',
#  'puerto ayora',
#  'saint george',
#  'ponta do sol',
#  'hermanus',
#  'kattivakkam',
#  'san ramon de la nueva oran',
#  'yellowknife',
#  'ulety',
#  'hithadhoo',
#  'port moresby',
#  'grootfontein',
#  'barroquinha',
#  'adrar',
#  'beringovskiy',
#  'dikson',
#  'comodoro rivadavia',
#  'nobres',
#  'margate',
#  'cherrapunji',
#  'nouadhibou',
#  'la ronge',
#  'amderma',
#  'cherskiy',
#  'vao',
#  'san jose',
#  'port elizabeth',
#  'taloqan',
#  'nome',
#  'prince rupert',
#  'vostok',
#  'padang',
#  'gurgan',
#  'riyadh',
#  'aksarka',
#  'jacqueville',
#  'chicama',
#  'cabo san lucas',
#  'wukari',
#  'acapulco',
#  'lebu',
#  'chokurdakh',
#  'pisco',
#  'severo-kurilsk',
#  'xiongzhou',
#  'bluff',
#  'krasnoselkup',
#  'gamba',
#  'bereda',
#  'butte',
#  'ilulissat',
#  'pangody',
#  'henties bay',
#  'clyde river',
#  'kavaratti',
#  'illoqqortoormiut',
#  'upata',
#  'faya',
#  'synya',
#  'batticaloa',
#  'salalah',
#  'zhireken',
#  'marawi',
#  'tasiilaq',
#  'coihaique',
#  'viedma',
#  'chuy',
#  'sabang',
#  'tiksi',
#  'castro',
#  'bac lieu',
#  'terrace',
#  'zolotinka',
#  'charters towers',
#  'narsaq',
#  'gaurnadi',
#  'airai',
#  'mujiayingzi',
#  'oriximina',
#  'louisbourg',
#  'cangzhou',
#  'lagoa',
#  'mahebourg',
#  'kilindoni',
#  'lantana',
#  'cabedelo',
#  'aripuana',
#  'constitucion',
#  'ayan',
#  'talawdi',
#  'umm lajj',
#  'adre',
#  'aklavik',
#  'bolungarvik',
#  'saint-philippe',
#  'nizhneyansk',
#  'ucluelet',
#  'khasan',
#  'magistralnyy',
#  'vestmannaeyjar',
#  'gao',
#  'codrington',
#  'muroto',
#  'samusu',
#  'dalvik',
#  'cuenca',
#  'balkhash',
#  'lata',
#  'sioux lookout',
#  'kutum',
#  'angol',
#  'tshikapa',
#  'nikolskoye',
#  'puerto leguizamo',
#  'bengkulu',
#  'maragogi',
#  'umba',
#  'hofn',
#  'escarcega',
#  'peleduy',
#  'nampa',
#  'belushya guba',
#  'new norfolk',
#  'puerto escondido',
#  'sug-aksy',
#  'aracati',
#  'naze',
#  'alto araguaia',
#  'east london',
#  'gornopravdinsk',
#  'rolla',
#  'caohe',
#  'chapleau',
#  'lufilufi',
#  'lorengau',
#  'pergamino',
#  'satitoa',
#  'atar',
#  'cockburn town',
#  'daru',
#  'port blair',
#  'ugoofaaru',
#  'birjand',
#  'makakilo city',
#  'westport',
#  'ancud',
#  'thunder bay',
#  'butaritari',
#  'dehloran',
#  'piacabucu',
#  'aguimes',
#  'kodiak',
#  'abu zabad',
#  'paraiso',
#  'aitape',
#  'rabak',
#  'verkhnyaya inta',
#  'manado',
#  'faanui',
#  'hovd',
#  'carupano',
#  'berlevag',
#  'nhulunbuy',
#  'anadyr',
#  'vila velha',
#  'norman wells',
#  'nautla',
#  'lolua',
#  'lovozero',
#  'guarapari',
#  'khorixas',
#  'moron',
#  'lucena',
#  'ormara',
#  'khed brahma',
#  'fereydun kenar',
#  'oshkosh',
#  'finschhafen',
#  'kupang',
#  'huarmey',
#  'lai',
#  'ahuimanu',
#  'kango',
#  'ndele',
#  'arraial do cabo',
#  'marcona',
#  'hami',
#  'nakambala',
#  'ust-kamchatsk',
#  'skibbereen',
#  'tuatapere',
#  'bitin',
#  'matara',
#  'port lincoln',
#  'yar-sale',
#  'pozega',
#  'alyangula',
#  'matagami',
#  'vila franca do campo',
#  'coquimbo',
#  'segovia',
#  'kalabo',
#  'georgetown',
#  'japura',
#  'esperance',
#  'usinsk',
#  'hamilton',
#  'sambava',
#  'tessalit',
#  'harper',
#  'svetlogorsk',
#  'verin',
#  'lasa',
#  'cartagena',
#  'kerman',
#  'severnyy',
#  'yatou',
#  'beloha',
#  'sao filipe',
#  'dubovskoye',
#  'ishim',
#  'zhoukou',
#  'stornoway',
#  'paita',
#  'payson',
#  'yomitan',
#  'nuevo imperial',
#  'yulara',
#  'pangoa',
#  'belaya gora',
#  'kavieng',
#  'tual',
#  'herat',
#  'kralendijk',
#  'tanout',
#  'banda aceh',
#  'bethel',
#  'yumbe',
#  'mastic beach',
#  'laguna',
#  'rovaniemi',
#  'san patricio',
#  'nayoro',
#  'bubaque',
#  'hunza',
#  'loubomo',
#  'mandan',
#  'puerto madryn',
#  'trinidad',
#  'karkaralinsk',
#  'havoysund',
#  'uhlove',
#  'praia da vitoria',
#  'nayudupeta',
#  'pangnirtung',
#  'gold coast',
#  'mopipi',
#  'zhezkazgan',
#  'sisimiut',
#  'mount gambier',
#  'la union',
#  'terme',
#  'mahon',
#  'lompoc',
#  'bure',
#  'vozrozhdeniye',
#  'burica',
#  'victor harbor',
#  'sao jose da coroa grande',
#  'kapasan',
#  'talnakh',
#  'nipawin',
#  'palmer',
#  'marystown',
#  'nokaneng',
#  'smithfield',
#  'alekseyevka',
#  'te anau',
#  'novorozhdestvenskaya',
#  'birao',
#  'grand gaube',
#  'armizonskoye',
#  'san vicente',
#  'opotiki',
#  'sentyabrskiy',
#  'longyearbyen',
#  'tiarei',
#  'vardo',
#  'kyra',
#  'boyolangu',
#  'vaitupu',
#  'doha',
#  'keuruu',
#  'memaliaj',
#  'guasdualito',
#  'slave lake',
#  'provideniya',
#  'attawapiskat',
#  'san jeronimo',
#  'masoko',
#  'homer',
#  'florianopolis',
#  'ca mau',
#  'mandera',
#  'los llanos de aridane',
#  'buchanan',
#  'sale',
#  'robe',
#  'college',
#  'haibowan',
#  'tolaga bay',
#  'tautira',
#  'tilichiki',
#  'souillac',
#  'khonuu',
#  'mangile',
#  'zhigansk',
#  'tartki',
#  'leningradskiy',
#  'qiongshan',
#  'rapid valley',
#  'bonthe',
#  'maceio',
#  'altamira',
#  'bhabua',
#  'marv dasht',
#  'luanda',
#  'zhicheng',
#  'ouesso',
#  'cozumel',
#  'ulaangom',
#  'bathsheba',
#  'shellbrook',
#  'coruripe',
#  'olafsvik',
#  'pacifica',
#  'rungata',
#  'sistranda',
#  'fort nelson',
#  'port hardy',
#  'vera cruz',
#  'luwuk',
#  'saint-louis',
#  'perle',
#  'vysokogornyy',
#  'tehri',
#  'algiers',
#  'solnechnyy',
#  'dargaville',
#  'atasu',
#  'tukrah',
#  'kasongo-lunda',
#  'bajil',
#  'meru',
#  'shingu',
#  'barbar',
#  'livingstonia',
#  'police',
#  'tarpon springs',
#  'pilao arcado',
#  'waipawa',
#  'kahului',
#  'antofagasta',
#  'ozernovskiy',
#  'tokur',
#  'rio gallegos',
#  'kaka',
#  'tezu',
#  'alofi',
#  'hambantota',
#  'tshela',
#  'presidente olegario',
#  'kununurra',
#  'taoudenni',
#  'nanortalik',
#  'chegutu',
#  'san cristobal',
#  'boende',
#  'chimore',
#  'lavrentiya',
#  'conceicao do araguaia',
#  'hervey bay',
#  'aykhal',
#  'meyungs',
#  'namagiripettai',
#  'yungay',
#  'fredericksburg',
#  'san quintin',
#  'mandurah',
#  'maneadero',
#  'obo',
#  'brooks',
#  'qasigiannguit',
#  'fukue',
#  'petropavlovsk-kamchatskiy',
#  'chilchotla',
#  'wahran',
#  'cumpas',
#  'anori',
#  'fairview',
#  'tukan',
#  'roald',
#  'zaplyusye',
#  'ngara',
#  'ganzhou',
#  'garm',
#  'severomorsk',
#  'formosa',
#  'mwene-ditu',
#  'kaniama',
#  'umtata',
#  'suez',
#  'tovuz',
#  'changzhou',
#  'manicore',
#  'nguiu',
#  'yabrud',
#  'ozgon',
#  'aksu',
#  'ixtapa',
#  'taraz',
#  'fortuna foothills',
#  'buritizeiro',
#  'ahipara',
#  'nioro',
#  'papillion',
#  'buala',
#  'mergui',
#  'kenmare',
#  'okhotsk',
#  'luganville',
#  'grand-santi',
#  'suntar',
#  'manaure',
#  'amet',
#  'pafos',
#  'srednekolymsk',
#  'wattegama',
#  'lakes entrance',
#  'massaguet',
#  'churapcha',
#  'brokopondo',
#  'maldonado',
#  'caravelas',
#  'kailua',
#  'auki',
#  'mys shmidta',
#  'biak',
#  'taiyuan',
#  'rincon',
#  'calama',
#  'mweka',
#  'baykit',
#  'cayenne',
#  'itoman',
#  'olinda',
#  'dori',
#  'maloshuyka',
#  'kiama',
#  'oussouye',
#  'tabiauea',
#  'ambodifototra',
#  'portland',
#  'jiangyou',
#  'tura',
#  'batagay-alyta',
#  'yangambi',
#  'najran',
#  'beloye',
#  'hayden',
#  'gazni',
#  'gigmoto',
#  'ulaanbaatar',
#  'haines junction',
#  'kloulklubed',
#  'talas',
#  'albenga',
#  'saint anthony',
#  'naryan-mar',
#  'iqaluit',
#  'vanimo',
#  'bajos de haina',
#  'tomari',
#  'yeppoon',
#  'jeremie',
#  'sinnamary',
#  'kamyshla',
#  'qaqortoq',
#  'longonjo',
#  'lensk',
#  'quipile',
#  'diffa',
#  'hobyo',
#  'middelburg',
#  'teruel',
#  'wasilla',
#  'lucea',
#  'zhongxing',
#  'otane',
#  'umzimvubu',
#  'tairua',
#  'benalla',
#  'ulladulla',
#  'chapulhuacan',
#  'san borja',
#  'izhma',
#  'flin flon',
#  'marquette',
#  'bambous virieux',
#  'tonota',
#  'yafran',
#  'tazovskiy',
#  'yerbogachen',
#  'chilca',
#  'kieta',
#  'luderitz',
#  'aflu',
#  'bend',
#  'moerai',
#  'lobito',
#  'shenjiamen',
#  'katherine',
#  'tall kayf',
#  'mamontovo',
#  'bilibino',
#  'phan rang',
#  'gacko',
#  'moussoro',
#  'morant bay']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4169ac228419eab3fd0b712403de2236

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_WX = city_weather["weather"][0]["description"]
        try:
            rain = city_weather["rain"]["1h"]
        except:
            rain = "0.0"
        try:
            snow = city_weather["snow"]["1h"]
        except:
            snow = "0.0"
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_WX,
                          "Rain (inches)": rain, #convert mm to in???
                          "Snow (inches)": snow
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eureka
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | raudeberg
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | ukiah
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | bilma
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 1 | umea
# Processing Record 23 of Set 1 | karratha
# Processing Record 24 of Set 1 | basse
# Processing Record 25 of Set 1 | pryazha
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | lahaina
# Processing Record 31 of Set 1 | mishan
# Processing Record 32 of Set 1 | mehamn
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | fairbanks
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | nadym
# Processing Record 38 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | quang ngai
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | adwa
# Processing Record 46 of Set 1 | sola
# Processing Record 47 of Set 1 | russell
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | guangyuan
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | ordzhonikidze
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | sao joao da barra
# Processing Record 6 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | lillooet
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | batagay
# Processing Record 12 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 2 | amqui
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | namatanai
# Processing Record 18 of Set 2 | havre-saint-pierre
# Processing Record 19 of Set 2 | isangel
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | atbasar
# Processing Record 23 of Set 2 | villefranche-sur-saone
# Processing Record 24 of Set 2 | guerrero negro
# Processing Record 25 of Set 2 | rio grande
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | buraydah
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | kattivakkam
# Processing Record 33 of Set 2 | san ramon de la nueva oran
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | ulety
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | port moresby
# Processing Record 38 of Set 2 | grootfontein
# Processing Record 39 of Set 2 | barroquinha
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | beringovskiy
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | comodoro rivadavia
# Processing Record 44 of Set 2 | nobres
# Processing Record 45 of Set 2 | margate
# Processing Record 46 of Set 2 | cherrapunji
# Processing Record 47 of Set 2 | nouadhibou
# Processing Record 48 of Set 2 | la ronge
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | vao
# Processing Record 2 of Set 3 | san jose
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | taloqan
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | prince rupert
# Processing Record 7 of Set 3 | vostok
# Processing Record 8 of Set 3 | padang
# Processing Record 9 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 3 | riyadh
# Processing Record 11 of Set 3 | aksarka
# Processing Record 12 of Set 3 | jacqueville
# Processing Record 13 of Set 3 | chicama
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | wukari
# Processing Record 16 of Set 3 | acapulco
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | severo-kurilsk
# Processing Record 21 of Set 3 | xiongzhou
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | krasnoselkup
# Processing Record 24 of Set 3 | gamba
# Processing Record 25 of Set 3 | bereda
# Processing Record 26 of Set 3 | butte
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | pangody
# Processing Record 29 of Set 3 | henties bay
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | upata
# Processing Record 34 of Set 3 | faya
# Processing Record 35 of Set 3 | synya
# Processing Record 36 of Set 3 | batticaloa
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | zhireken
# Processing Record 39 of Set 3 | marawi
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | viedma
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | sabang
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | bac lieu
# Processing Record 48 of Set 3 | terrace
# Processing Record 49 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 50 of Set 3 | charters towers
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | gaurnadi
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | mujiayingzi
# Processing Record 5 of Set 4 | oriximina
# Processing Record 6 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 4 | cangzhou
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | kilindoni
# Processing Record 11 of Set 4 | lantana
# Processing Record 12 of Set 4 | cabedelo
# Processing Record 13 of Set 4 | aripuana
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | ayan
# Processing Record 16 of Set 4 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 4 | umm lajj
# Processing Record 18 of Set 4 | adre
# Processing Record 19 of Set 4 | aklavik
# Processing Record 20 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | ucluelet
# Processing Record 24 of Set 4 | khasan
# Processing Record 25 of Set 4 | magistralnyy
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | gao
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | muroto
# Processing Record 30 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 4 | dalvik
# Processing Record 32 of Set 4 | cuenca
# Processing Record 33 of Set 4 | balkhash
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | sioux lookout
# Processing Record 36 of Set 4 | kutum
# Processing Record 37 of Set 4 | angol
# Processing Record 38 of Set 4 | tshikapa
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | puerto leguizamo
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | maragogi
# Processing Record 43 of Set 4 | umba
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | escarcega
# Processing Record 46 of Set 4 | peleduy
# Processing Record 47 of Set 4 | nampa
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | puerto escondido
# Processing Record 1 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 2 of Set 5 | aracati
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | alto araguaia
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | gornopravdinsk
# Processing Record 7 of Set 5 | rolla
# Processing Record 8 of Set 5 | caohe
# Processing Record 9 of Set 5 | chapleau
# Processing Record 10 of Set 5 | lufilufi
# Processing Record 11 of Set 5 | lorengau
# Processing Record 12 of Set 5 | pergamino
# Processing Record 13 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | daru
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | ugoofaaru
# Processing Record 19 of Set 5 | birjand
# Processing Record 20 of Set 5 | makakilo city
# Processing Record 21 of Set 5 | westport
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | thunder bay
# Processing Record 24 of Set 5 | butaritari
# Processing Record 25 of Set 5 | dehloran
# Processing Record 26 of Set 5 | piacabucu
# Processing Record 27 of Set 5 | aguimes
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | abu zabad
# Processing Record 30 of Set 5 | paraiso
# Processing Record 31 of Set 5 | aitape
# Processing Record 32 of Set 5 | rabak
# Processing Record 33 of Set 5 | verkhnyaya inta
# Processing Record 34 of Set 5 | manado
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | hovd
# Processing Record 37 of Set 5 | carupano
# Processing Record 38 of Set 5 | berlevag
# Processing Record 39 of Set 5 | nhulunbuy
# Processing Record 40 of Set 5 | anadyr
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | nautla
# Processing Record 44 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 5 | lovozero
# Processing Record 46 of Set 5 | guarapari
# Processing Record 47 of Set 5 | khorixas
# Processing Record 48 of Set 5 | moron
# Processing Record 49 of Set 5 | lucena
# Processing Record 50 of Set 5 | ormara
# Processing Record 1 of Set 6 | khed brahma
# Processing Record 2 of Set 6 | fereydun kenar
# Processing Record 3 of Set 6 | oshkosh
# Processing Record 4 of Set 6 | finschhafen
# Processing Record 5 of Set 6 | kupang
# Processing Record 6 of Set 6 | huarmey
# Processing Record 7 of Set 6 | lai
# Processing Record 8 of Set 6 | ahuimanu
# Processing Record 9 of Set 6 | kango
# Processing Record 10 of Set 6 | ndele
# Processing Record 11 of Set 6 | arraial do cabo
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | nakambala
# Processing Record 15 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 6 | skibbereen
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | bitin
# Processing Record 19 of Set 6 | matara
# Processing Record 20 of Set 6 | port lincoln
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | pozega
# Processing Record 23 of Set 6 | alyangula
# Processing Record 24 of Set 6 | matagami
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | segovia
# Processing Record 28 of Set 6 | kalabo
# Processing Record 29 of Set 6 | georgetown
# Processing Record 30 of Set 6 | japura
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | usinsk
# Processing Record 33 of Set 6 | hamilton
# Processing Record 34 of Set 6 | sambava
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | harper
# Processing Record 37 of Set 6 | svetlogorsk
# Processing Record 38 of Set 6 | verin
# Processing Record 39 of Set 6 | lasa
# Processing Record 40 of Set 6 | cartagena
# Processing Record 41 of Set 6 | kerman
# Processing Record 42 of Set 6 | severnyy
# Processing Record 43 of Set 6 | yatou
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | dubovskoye
# Processing Record 47 of Set 6 | ishim
# Processing Record 48 of Set 6 | zhoukou
# Processing Record 49 of Set 6 | stornoway
# Processing Record 50 of Set 6 | paita
# Processing Record 1 of Set 7 | payson
# Processing Record 2 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 7 | nuevo imperial
# Processing Record 4 of Set 7 | yulara
# Processing Record 5 of Set 7 | pangoa
# Processing Record 6 of Set 7 | belaya gora
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | tual
# Processing Record 9 of Set 7 | herat
# Processing Record 10 of Set 7 | kralendijk
# Processing Record 11 of Set 7 | tanout
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | bethel
# Processing Record 14 of Set 7 | yumbe
# Processing Record 15 of Set 7 | mastic beach
# Processing Record 16 of Set 7 | laguna
# Processing Record 17 of Set 7 | rovaniemi
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | nayoro
# Processing Record 20 of Set 7 | bubaque
# Processing Record 21 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 7 | loubomo
# Processing Record 23 of Set 7 | mandan
# Processing Record 24 of Set 7 | puerto madryn
# Processing Record 25 of Set 7 | trinidad
# Processing Record 26 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | havoysund
# Processing Record 28 of Set 7 | uhlove
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | nayudupeta
# Processing Record 31 of Set 7 | pangnirtung
# Processing Record 32 of Set 7 | gold coast
# Processing Record 33 of Set 7 | mopipi
# Processing Record 34 of Set 7 | zhezkazgan
# Processing Record 35 of Set 7 | sisimiut
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | la union
# Processing Record 38 of Set 7 | terme
# Processing Record 39 of Set 7 | mahon
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | bure
# Processing Record 42 of Set 7 | vozrozhdeniye
# Processing Record 43 of Set 7 | burica
# City not found. Skipping...
# Processing Record 44 of Set 7 | victor harbor
# Processing Record 45 of Set 7 | sao jose da coroa grande
# Processing Record 46 of Set 7 | kapasan
# Processing Record 47 of Set 7 | talnakh
# Processing Record 48 of Set 7 | nipawin
# Processing Record 49 of Set 7 | palmer
# Processing Record 50 of Set 7 | marystown
# Processing Record 1 of Set 8 | nokaneng
# Processing Record 2 of Set 8 | smithfield
# Processing Record 3 of Set 8 | alekseyevka
# Processing Record 4 of Set 8 | te anau
# Processing Record 5 of Set 8 | novorozhdestvenskaya
# Processing Record 6 of Set 8 | birao
# Processing Record 7 of Set 8 | grand gaube
# Processing Record 8 of Set 8 | armizonskoye
# Processing Record 9 of Set 8 | san vicente
# Processing Record 10 of Set 8 | opotiki
# Processing Record 11 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | tiarei
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | kyra
# Processing Record 16 of Set 8 | boyolangu
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | doha
# Processing Record 19 of Set 8 | keuruu
# Processing Record 20 of Set 8 | memaliaj
# Processing Record 21 of Set 8 | guasdualito
# Processing Record 22 of Set 8 | slave lake
# Processing Record 23 of Set 8 | provideniya
# Processing Record 24 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 8 | san jeronimo
# Processing Record 26 of Set 8 | masoko
# Processing Record 27 of Set 8 | homer
# Processing Record 28 of Set 8 | florianopolis
# Processing Record 29 of Set 8 | ca mau
# Processing Record 30 of Set 8 | mandera
# Processing Record 31 of Set 8 | los llanos de aridane
# Processing Record 32 of Set 8 | buchanan
# Processing Record 33 of Set 8 | sale
# Processing Record 34 of Set 8 | robe
# Processing Record 35 of Set 8 | college
# Processing Record 36 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 8 | tolaga bay
# Processing Record 38 of Set 8 | tautira
# Processing Record 39 of Set 8 | tilichiki
# Processing Record 40 of Set 8 | souillac
# Processing Record 41 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 8 | mangile
# City not found. Skipping...
# Processing Record 43 of Set 8 | zhigansk
# Processing Record 44 of Set 8 | tartki
# City not found. Skipping...
# Processing Record 45 of Set 8 | leningradskiy
# Processing Record 46 of Set 8 | qiongshan
# Processing Record 47 of Set 8 | rapid valley
# Processing Record 48 of Set 8 | bonthe
# Processing Record 49 of Set 8 | maceio
# Processing Record 50 of Set 8 | altamira
# Processing Record 1 of Set 9 | bhabua
# Processing Record 2 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 3 of Set 9 | luanda
# Processing Record 4 of Set 9 | zhicheng
# Processing Record 5 of Set 9 | ouesso
# Processing Record 6 of Set 9 | cozumel
# Processing Record 7 of Set 9 | ulaangom
# Processing Record 8 of Set 9 | bathsheba
# Processing Record 9 of Set 9 | shellbrook
# Processing Record 10 of Set 9 | coruripe
# Processing Record 11 of Set 9 | olafsvik
# Processing Record 12 of Set 9 | pacifica
# Processing Record 13 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 9 | sistranda
# Processing Record 15 of Set 9 | fort nelson
# Processing Record 16 of Set 9 | port hardy
# Processing Record 17 of Set 9 | vera cruz
# Processing Record 18 of Set 9 | luwuk
# Processing Record 19 of Set 9 | saint-louis
# Processing Record 20 of Set 9 | perle
# Processing Record 21 of Set 9 | vysokogornyy
# Processing Record 22 of Set 9 | tehri
# Processing Record 23 of Set 9 | algiers
# Processing Record 24 of Set 9 | solnechnyy
# Processing Record 25 of Set 9 | dargaville
# Processing Record 26 of Set 9 | atasu
# Processing Record 27 of Set 9 | tukrah
# Processing Record 28 of Set 9 | kasongo-lunda
# Processing Record 29 of Set 9 | bajil
# Processing Record 30 of Set 9 | meru
# Processing Record 31 of Set 9 | shingu
# Processing Record 32 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 9 | livingstonia
# Processing Record 34 of Set 9 | police
# Processing Record 35 of Set 9 | tarpon springs
# Processing Record 36 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 37 of Set 9 | waipawa
# Processing Record 38 of Set 9 | kahului
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | ozernovskiy
# Processing Record 41 of Set 9 | tokur
# Processing Record 42 of Set 9 | rio gallegos
# Processing Record 43 of Set 9 | kaka
# Processing Record 44 of Set 9 | tezu
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | hambantota
# Processing Record 47 of Set 9 | tshela
# Processing Record 48 of Set 9 | presidente olegario
# Processing Record 49 of Set 9 | kununurra
# Processing Record 50 of Set 9 | taoudenni
# Processing Record 1 of Set 10 | nanortalik
# Processing Record 2 of Set 10 | chegutu
# Processing Record 3 of Set 10 | san cristobal
# Processing Record 4 of Set 10 | boende
# Processing Record 5 of Set 10 | chimore
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | conceicao do araguaia
# Processing Record 8 of Set 10 | hervey bay
# Processing Record 9 of Set 10 | aykhal
# Processing Record 10 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 10 | namagiripettai
# Processing Record 12 of Set 10 | yungay
# Processing Record 13 of Set 10 | fredericksburg
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | mandurah
# Processing Record 16 of Set 10 | maneadero
# Processing Record 17 of Set 10 | obo
# Processing Record 18 of Set 10 | brooks
# Processing Record 19 of Set 10 | qasigiannguit
# Processing Record 20 of Set 10 | fukue
# Processing Record 21 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 10 | chilchotla
# Processing Record 23 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 10 | cumpas
# Processing Record 25 of Set 10 | anori
# Processing Record 26 of Set 10 | fairview
# Processing Record 27 of Set 10 | tukan
# Processing Record 28 of Set 10 | roald
# Processing Record 29 of Set 10 | zaplyusye
# City not found. Skipping...
# Processing Record 30 of Set 10 | ngara
# Processing Record 31 of Set 10 | ganzhou
# Processing Record 32 of Set 10 | garm
# City not found. Skipping...
# Processing Record 33 of Set 10 | severomorsk
# Processing Record 34 of Set 10 | formosa
# Processing Record 35 of Set 10 | mwene-ditu
# Processing Record 36 of Set 10 | kaniama
# Processing Record 37 of Set 10 | umtata
# Processing Record 38 of Set 10 | suez
# Processing Record 39 of Set 10 | tovuz
# Processing Record 40 of Set 10 | changzhou
# Processing Record 41 of Set 10 | manicore
# Processing Record 42 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 10 | yabrud
# Processing Record 44 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | ixtapa
# Processing Record 47 of Set 10 | taraz
# Processing Record 48 of Set 10 | fortuna foothills
# Processing Record 49 of Set 10 | buritizeiro
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | nioro
# Processing Record 2 of Set 11 | papillion
# Processing Record 3 of Set 11 | buala
# Processing Record 4 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 11 | kenmare
# Processing Record 6 of Set 11 | okhotsk
# Processing Record 7 of Set 11 | luganville
# Processing Record 8 of Set 11 | grand-santi
# Processing Record 9 of Set 11 | suntar
# Processing Record 10 of Set 11 | manaure
# Processing Record 11 of Set 11 | amet
# Processing Record 12 of Set 11 | pafos
# Processing Record 13 of Set 11 | srednekolymsk
# Processing Record 14 of Set 11 | wattegama
# Processing Record 15 of Set 11 | lakes entrance
# Processing Record 16 of Set 11 | massaguet
# Processing Record 17 of Set 11 | churapcha
# Processing Record 18 of Set 11 | brokopondo
# Processing Record 19 of Set 11 | maldonado
# Processing Record 20 of Set 11 | caravelas
# Processing Record 21 of Set 11 | kailua
# Processing Record 22 of Set 11 | auki
# Processing Record 23 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 11 | biak
# Processing Record 25 of Set 11 | taiyuan
# Processing Record 26 of Set 11 | rincon
# Processing Record 27 of Set 11 | calama
# Processing Record 28 of Set 11 | mweka
# Processing Record 29 of Set 11 | baykit
# Processing Record 30 of Set 11 | cayenne
# Processing Record 31 of Set 11 | itoman
# Processing Record 32 of Set 11 | olinda
# Processing Record 33 of Set 11 | dori
# Processing Record 34 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 35 of Set 11 | kiama
# Processing Record 36 of Set 11 | oussouye
# Processing Record 37 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 11 | portland
# Processing Record 40 of Set 11 | jiangyou
# Processing Record 41 of Set 11 | tura
# Processing Record 42 of Set 11 | batagay-alyta
# Processing Record 43 of Set 11 | yangambi
# Processing Record 44 of Set 11 | najran
# Processing Record 45 of Set 11 | beloye
# Processing Record 46 of Set 11 | hayden
# Processing Record 47 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 11 | gigmoto
# Processing Record 49 of Set 11 | ulaanbaatar
# Processing Record 50 of Set 11 | haines junction
# Processing Record 1 of Set 12 | kloulklubed
# Processing Record 2 of Set 12 | talas
# Processing Record 3 of Set 12 | albenga
# Processing Record 4 of Set 12 | saint anthony
# Processing Record 5 of Set 12 | naryan-mar
# Processing Record 6 of Set 12 | iqaluit
# Processing Record 7 of Set 12 | vanimo
# Processing Record 8 of Set 12 | bajos de haina
# Processing Record 9 of Set 12 | tomari
# Processing Record 10 of Set 12 | yeppoon
# Processing Record 11 of Set 12 | jeremie
# Processing Record 12 of Set 12 | sinnamary
# Processing Record 13 of Set 12 | kamyshla
# Processing Record 14 of Set 12 | qaqortoq
# Processing Record 15 of Set 12 | longonjo
# Processing Record 16 of Set 12 | lensk
# Processing Record 17 of Set 12 | quipile
# Processing Record 18 of Set 12 | diffa
# Processing Record 19 of Set 12 | hobyo
# Processing Record 20 of Set 12 | middelburg
# Processing Record 21 of Set 12 | teruel
# Processing Record 22 of Set 12 | wasilla
# Processing Record 23 of Set 12 | lucea
# Processing Record 24 of Set 12 | zhongxing
# Processing Record 25 of Set 12 | otane
# Processing Record 26 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 12 | tairua
# Processing Record 28 of Set 12 | benalla
# Processing Record 29 of Set 12 | ulladulla
# Processing Record 30 of Set 12 | chapulhuacan
# Processing Record 31 of Set 12 | san borja
# Processing Record 32 of Set 12 | izhma
# Processing Record 33 of Set 12 | flin flon
# Processing Record 34 of Set 12 | marquette
# Processing Record 35 of Set 12 | bambous virieux
# Processing Record 36 of Set 12 | tonota
# Processing Record 37 of Set 12 | yafran
# Processing Record 38 of Set 12 | tazovskiy
# Processing Record 39 of Set 12 | yerbogachen
# Processing Record 40 of Set 12 | chilca
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | luderitz
# Processing Record 43 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 12 | bend
# Processing Record 45 of Set 12 | moerai
# Processing Record 46 of Set 12 | lobito
# Processing Record 47 of Set 12 | shenjiamen
# Processing Record 48 of Set 12 | katherine
# Processing Record 49 of Set 12 | tall kayf
# Processing Record 50 of Set 12 | mamontovo
# Processing Record 1 of Set 13 | bilibino
# Processing Record 2 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 13 | gacko
# Processing Record 4 of Set 13 | moussoro
# Processing Record 5 of Set 13 | morant bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Eureka      US  40.80 -124.16     66.99         6          10
# 1     Upernavik      GL  72.79  -56.15     44.26        68          50
# 2        Hasaki      JP  35.73  140.83     82.00        83          75
# 3       Ushuaia      AR -54.80  -68.30     41.00        65          75
# 4      Khatanga      RU  71.97  102.50     52.79        64          57
# ..          ...     ...    ...     ...       ...       ...         ...
# 547   Mamontovo      RU  52.71   81.62     61.95        86         100
# 548    Bilibino      RU  68.05  166.44     63.27        49          59
# 549       Gacko      BA  43.17   18.54     64.40        52          20
# 550    Moussoro      TD  13.64   16.49     89.13        44          42
# 551  Morant Bay      JM  17.88  -76.41     87.80        70          40
#
#      Wind Speed Current Description Rain (inches) Snow (inches)
# 0          5.99           clear sky           0.0           0.0
# 1          8.34    scattered clouds           0.0           0.0
# 2         11.41       broken clouds           0.0           0.0
# 3         18.34         shower rain           0.0           0.0
# 4         16.62       broken clouds           0.0           0.0
# ..          ...                 ...           ...           ...
# 547        3.38     overcast clouds           0.0           0.0
# 548        8.72          light rain          0.45           0.0
# 549        3.36          few clouds           0.0           0.0
# 550        7.76    scattered clouds           0.0           0.0
# 551       19.46    scattered clouds           0.0           0.0
#
# [552 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
