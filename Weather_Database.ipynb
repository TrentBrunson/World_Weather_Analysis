# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests # Import the requests library.

# Import the weather API key.
from config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(len(cities))
cities
# Out:
# 632
# ['kralendijk',
#  'puerto lumbreras',
#  'belaya gora',
#  'taolanaro',
#  'rodeo',
#  'ushuaia',
#  'ribeira grande',
#  'azimur',
#  'mataura',
#  'namtsy',
#  'lagoa',
#  'beinamar',
#  'geraldton',
#  'hermanus',
#  'mys shmidta',
#  'busselton',
#  'mount isa',
#  'gravdal',
#  'bluff',
#  'tiksi',
#  'mizdah',
#  'kapaa',
#  'attawapiskat',
#  'port alfred',
#  'safford',
#  'vardo',
#  'vaini',
#  'jamestown',
#  'qaanaaq',
#  'noumea',
#  'verkhoyansk',
#  'bambous virieux',
#  'atuona',
#  'bengkulu',
#  'punta arenas',
#  'arraial do cabo',
#  'winnemucca',
#  'rikitea',
#  'mahebourg',
#  'carnarvon',
#  'grand-lahou',
#  'cunduacan',
#  'mehamn',
#  'meyungs',
#  'puerto ayora',
#  'fortuna',
#  'albany',
#  'new norfolk',
#  'hobart',
#  'alofi',
#  'hilo',
#  'kuche',
#  'georgetown',
#  'barrow',
#  'belushya guba',
#  'dunedin',
#  'katsuura',
#  'yellowknife',
#  'titlagarh',
#  'kerman',
#  'aklavik',
#  'karratha',
#  'russell',
#  'darhan',
#  'san vicente',
#  'bucerias',
#  'sheltozero',
#  'saint george',
#  'nioro',
#  'chokurdakh',
#  'hobyo',
#  'pevek',
#  'melaka',
#  'vaitupu',
#  'tuatapere',
#  'luderitz',
#  'basco',
#  'douentza',
#  'xai-xai',
#  'zeerust',
#  'saint-philippe',
#  'payakumbuh',
#  'kavieng',
#  'gilgit',
#  'ipixuna',
#  'codrington',
#  'nizhneyansk',
#  'provideniya',
#  'mar del plata',
#  'riviere-au-renard',
#  'port lincoln',
#  'dingle',
#  'grand river south east',
#  'castro',
#  'chara',
#  'padang',
#  'rosarito',
#  'acapulco',
#  'khatanga',
#  'hithadhoo',
#  'soverato',
#  'victoria',
#  'avera',
#  'souillac',
#  'kloulklubed',
#  'mahadday weyne',
#  'volterra',
#  'gondanglegi',
#  'asau',
#  'gambela',
#  'scottsboro',
#  'kijang',
#  'sosua',
#  'kodiak',
#  'kibre mengist',
#  'san quintin',
#  'bhan',
#  'khandyga',
#  'dalbandin',
#  'bur gabo',
#  'sentyabrskiy',
#  'bilibino',
#  'taos',
#  'karla',
#  'sassandra',
#  'arona',
#  'mantua',
#  'cape town',
#  'tsihombe',
#  'bereda',
#  'san patricio',
#  'boyolangu',
#  'galich',
#  'santa cruz',
#  'urumqi',
#  'aripuana',
#  'san cristobal',
#  'salalah',
#  'del rio',
#  'barbar',
#  'east london',
#  'itarema',
#  'coquimbo',
#  'chuy',
#  'tawzar',
#  'caravelas',
#  'avarua',
#  'novopavlovka',
#  'bandarbeyla',
#  'muli',
#  'kaeo',
#  'kaitangata',
#  'potosi',
#  'bredasdorp',
#  'uige',
#  'banepa',
#  'upernavik',
#  'aasiaat',
#  'katobu',
#  'chipinge',
#  'hirara',
#  'palatka',
#  'hasaki',
#  'impfondo',
#  'port hardy',
#  'nalut',
#  'cabo san lucas',
#  'hamilton',
#  'arica',
#  'baherden',
#  'lebu',
#  'korla',
#  'nikolskoye',
#  'egvekinot',
#  'dikson',
#  'alekseyevsk',
#  'gat',
#  'trofors',
#  'mengyin',
#  'san rafael',
#  'clonakilty',
#  'butaritari',
#  'panambi',
#  'lompoc',
#  'mamou',
#  'lexington',
#  'te anau',
#  'torbay',
#  'broken hill',
#  'la ronge',
#  'bilma',
#  'perth',
#  'muros',
#  'isangel',
#  'leningradskiy',
#  'conceicao do araguaia',
#  'bethel',
#  'talegaon dabhade',
#  'vresina',
#  'ginir',
#  'boundiali',
#  'havre-saint-pierre',
#  'atherton',
#  'qaqortoq',
#  'kosh-agach',
#  'migori',
#  'cherskiy',
#  'general roca',
#  'doha',
#  'nanortalik',
#  'northam',
#  'lashio',
#  'faanui',
#  'ponta do sol',
#  'hambantota',
#  'norman wells',
#  'kupang',
#  'zlatoustovsk',
#  'conguaco',
#  'silver city',
#  'willowmore',
#  'saleaula',
#  'umm lajj',
#  'samusu',
#  'lumphat',
#  'beyneu',
#  'destin',
#  'college',
#  'irece',
#  'amderma',
#  'moramanga',
#  'teguldet',
#  'dzhusaly',
#  'sagaing',
#  'bela',
#  'tura',
#  'hunza',
#  'delmas',
#  'lahij',
#  'rawson',
#  'funtua',
#  'bahia blanca',
#  'chongoyape',
#  'pisco',
#  'tautira',
#  'bathsheba',
#  'hami',
#  'candawaga',
#  'sri aman',
#  'bowling green',
#  'illoqqortoormiut',
#  'ostrovnoy',
#  'kyabe',
#  'touros',
#  'roanoke rapids',
#  'lavrentiya',
#  'meulaboh',
#  'comodoro rivadavia',
#  'ahuimanu',
#  'broome',
#  'saldanha',
#  'komsomolskiy',
#  'kismayo',
#  'concarneau',
#  'auki',
#  'karaul',
#  'palabuhanratu',
#  'lenger',
#  'scarborough',
#  'manyana',
#  'tumannyy',
#  'tanout',
#  'kachug',
#  'townsville',
#  'gushikawa',
#  'mazyr',
#  'lodwar',
#  'great falls',
#  'fort saint james',
#  'tezu',
#  'ketchikan',
#  'santiago',
#  'clyde river',
#  'esperance',
#  'beidao',
#  'mingguang',
#  'balikpapan',
#  'loreto',
#  'yulara',
#  'adrar',
#  'lazaro cardenas',
#  'yatou',
#  'laguna',
#  'westport',
#  'hutchinson',
#  'wladyslawowo',
#  'klaksvik',
#  'at-bashi',
#  'namibe',
#  'usolye-sibirskoye',
#  'pareora',
#  'yumen',
#  'nabire',
#  'magaria',
#  'constitucion',
#  'narsaq',
#  'zhigansk',
#  'viedma',
#  'puerto leguizamo',
#  'orodara',
#  'tiarei',
#  'vao',
#  'malindi',
#  'badiraguato',
#  'bemidji',
#  'sao filipe',
#  'namatanai',
#  'nadym',
#  'tyukhtet',
#  'nizhniy kuranakh',
#  'kibala',
#  'la troncal',
#  'half moon bay',
#  'port hedland',
#  'husavik',
#  'joshimath',
#  'mount gambier',
#  'sosnovo-ozerskoye',
#  'itacarambi',
#  'port elizabeth',
#  'bolivar',
#  'tucuma',
#  'port blair',
#  'havoysund',
#  'carutapera',
#  'saint-augustin',
#  'poum',
#  'shimoda',
#  'lufilufi',
#  'fort wellington',
#  'severo-kurilsk',
#  'agboville',
#  'praxedis guerrero',
#  'thompson',
#  'lakatoro',
#  'manoel urbano',
#  'morondava',
#  'santa isabel do rio negro',
#  'sorland',
#  'luwuk',
#  'fengkou',
#  'mogadishu',
#  'ekibastuz',
#  'alugan',
#  'lewistown',
#  'barentsburg',
#  'chifeng',
#  'tasiilaq',
#  'yazman',
#  'quatre cocos',
#  'bintulu',
#  'qasigiannguit',
#  'grindavik',
#  'henties bay',
#  'bonoua',
#  'okhotsk',
#  'lewisporte',
#  'vila franca do campo',
#  'long eaton',
#  'thinadhoo',
#  'xihua',
#  'bonfim',
#  'cururupu',
#  'umzimvubu',
#  'belmonte',
#  'zelenoborskiy',
#  'nouadhibou',
#  'suoyarvi',
#  'pauini',
#  'bargal',
#  'itoman',
#  'almeirim',
#  'alyangula',
#  'pontianak',
#  'tuktoyaktuk',
#  'gremyachye',
#  'esna',
#  'warqla',
#  'lahaina',
#  'ruteng',
#  'port macquarie',
#  'baracoa',
#  'longyearbyen',
#  'aflu',
#  'beringovskiy',
#  'ayacucho',
#  'san jose',
#  'talcahuano',
#  'abu dhabi',
#  'evensk',
#  'wenling',
#  'jaguaribe',
#  'kartaly',
#  'solnechnyy',
#  'bukama',
#  'brest',
#  'necochea',
#  'dinard',
#  'olafsvik',
#  'lons',
#  'valle de allende',
#  'aros',
#  'mina',
#  'penzance',
#  'cacapava do sul',
#  'lorengau',
#  'kudahuvadhoo',
#  'muroto',
#  'pontes e lacerda',
#  'ahipara',
#  'goderich',
#  'kemise',
#  'rundu',
#  'iqaluit',
#  'portland',
#  'vanimo',
#  'gurupa',
#  'sibolga',
#  'artigas',
#  'puerto pinasco',
#  'the valley',
#  'portachuelo',
#  'ampanihy',
#  'christchurch',
#  'flinders',
#  'taltal',
#  'kota belud',
#  'xichang',
#  'rio cuarto',
#  'rovaniemi',
#  'ambon',
#  'kenai',
#  'yanam',
#  'turayf',
#  'guarapari',
#  'sapa',
#  'kahului',
#  'punta alta',
#  'akropong',
#  'sitka',
#  'elizabeth city',
#  'leh',
#  'ugoofaaru',
#  'zeya',
#  'kisesa',
#  'farafangana',
#  'kleck',
#  'baiyin',
#  'markova',
#  'kruisfontein',
#  'olinda',
#  'kamenskoye',
#  'ust-kuyga',
#  'marzuq',
#  'saskylakh',
#  'yining',
#  'richards bay',
#  'hermosillo',
#  'barcelos',
#  'khasan',
#  'maun',
#  'brae',
#  'honiara',
#  'copiapo',
#  'sistranda',
#  'wulanhaote',
#  'doka',
#  'ancud',
#  'racale',
#  'amapa',
#  'weener',
#  'santa fe',
#  'sambava',
#  'lao cai',
#  'dongzhen',
#  'fevralsk',
#  'butembo',
#  'raglan',
#  'moose factory',
#  'kamaishi',
#  'lolua',
#  'lieksa',
#  'bambanglipuro',
#  'ilo',
#  'steinbach',
#  'wichita falls',
#  'khonsa',
#  'cidreira',
#  'arman',
#  'houma',
#  'gizo',
#  'riyadh',
#  'severo-yeniseyskiy',
#  'marsh harbour',
#  'halalo',
#  'fairbanks',
#  'manicore',
#  'fayaoue',
#  'saint-georges',
#  'kieta',
#  'wanning',
#  'tarko-sale',
#  'abu kamal',
#  'cap malheureux',
#  'manzanillo',
#  'coahuayana',
#  'shenjiamen',
#  'leshukonskoye',
#  'shchuchye',
#  'katangli',
#  'along',
#  'la mana',
#  'maragogi',
#  'dasoguz',
#  'mackay',
#  'fengrun',
#  'berlevag',
#  'grenville',
#  'waipawa',
#  'banjar',
#  'ngukurr',
#  'sarahan',
#  'manokwari',
#  'altamont',
#  'porto walter',
#  'sao felix do xingu',
#  'naspur',
#  'petauke',
#  'sangar',
#  'loubomo',
#  'gashua',
#  'sabang',
#  'malanje',
#  'calama',
#  'bundaberg',
#  'nome',
#  'sakakah',
#  'diffa',
#  'ismailia',
#  'sindand',
#  'upata',
#  'seoul',
#  'praya',
#  'kayes',
#  'kampot',
#  'himora',
#  'sydney',
#  'fare',
#  'ferrol',
#  'moron',
#  'agdas',
#  'gumdag',
#  'suluq',
#  'senanga',
#  'pacific grove',
#  'longonjo',
#  'la palma',
#  'dmitriyev-lgovskiy',
#  'romanovka',
#  'halmstad',
#  'flin flon',
#  'lima',
#  'walvis bay',
#  'ilulissat',
#  'coatzintla',
#  'dongfeng',
#  'ucluelet',
#  'oksfjord',
#  'nguiu',
#  'atka',
#  'bara',
#  'netarhat',
#  'nantucket',
#  'vizinga',
#  'nuuk',
#  'petropavlovsk-kamchatskiy',
#  'kapoeta',
#  'qandala',
#  'rafai',
#  'queimadas',
#  'andenes',
#  'vallenar',
#  'mrirt',
#  'bac lieu',
#  'sur',
#  'tilichiki',
#  'raga',
#  'vostok',
#  'ust-tarka',
#  'yerbogachen',
#  'fort nelson',
#  'hare bay',
#  'igarka',
#  'casa nova',
#  'cubara',
#  'ereymentau',
#  'ati',
#  'nurota',
#  'taicheng',
#  'berlin',
#  'sabha',
#  'karkaralinsk',
#  'kaliganj',
#  'suez',
#  'port-gentil',
#  'torrington',
#  'castro-urdiales',
#  'cobija',
#  'tazovskiy',
#  'ballitoville',
#  'batagay',
#  'yenagoa',
#  'buala',
#  'clearwater',
#  'ust-nera',
#  'kiama',
#  'lata',
#  'seinajoki',
#  'north bend',
#  'cascais',
#  'kimberley',
#  'casablanca']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4169ac228419eab3fd0b712403de2236

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_WX = city_weather["weather"][0]["description"]
        try:
            rain = city_weather["rain"]["rain.1h"]
        except:
            rain = "0.0"
        try:
            snow = city_weather["snow"]["snow.1h"]
        except:
            snow = "0.0"
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_WX,
                          "Rain (inches)": rain, #convert mm to in???
                          "Snow (inches)": snow
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kralendijk
# Processing Record 2 of Set 1 | puerto lumbreras
# Processing Record 3 of Set 1 | belaya gora
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | rodeo
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | namtsy
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | beinamar
# Processing Record 13 of Set 1 | geraldton
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | gravdal
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | mizdah
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | safford
# Processing Record 26 of Set 1 | vardo
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | noumea
# Processing Record 31 of Set 1 | verkhoyansk
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | winnemucca
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | grand-lahou
# Processing Record 42 of Set 1 | cunduacan
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | titlagarh
# Processing Record 10 of Set 2 | kerman
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | karratha
# Processing Record 13 of Set 2 | russell
# Processing Record 14 of Set 2 | darhan
# Processing Record 15 of Set 2 | san vicente
# Processing Record 16 of Set 2 | bucerias
# Processing Record 17 of Set 2 | sheltozero
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | nioro
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | hobyo
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | melaka
# Processing Record 24 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | basco
# Processing Record 28 of Set 2 | douentza
# Processing Record 29 of Set 2 | xai-xai
# Processing Record 30 of Set 2 | zeerust
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | payakumbuh
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | gilgit
# Processing Record 35 of Set 2 | ipixuna
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | riviere-au-renard
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | chara
# Processing Record 46 of Set 2 | padang
# Processing Record 47 of Set 2 | rosarito
# Processing Record 48 of Set 2 | acapulco
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | soverato
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | avera
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 3 | volterra
# Processing Record 8 of Set 3 | gondanglegi
# Processing Record 9 of Set 3 | asau
# Processing Record 10 of Set 3 | gambela
# Processing Record 11 of Set 3 | scottsboro
# Processing Record 12 of Set 3 | kijang
# Processing Record 13 of Set 3 | sosua
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | kibre mengist
# Processing Record 16 of Set 3 | san quintin
# Processing Record 17 of Set 3 | bhan
# Processing Record 18 of Set 3 | khandyga
# Processing Record 19 of Set 3 | dalbandin
# Processing Record 20 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | bilibino
# Processing Record 23 of Set 3 | taos
# Processing Record 24 of Set 3 | karla
# Processing Record 25 of Set 3 | sassandra
# Processing Record 26 of Set 3 | arona
# Processing Record 27 of Set 3 | mantua
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | bereda
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | boyolangu
# Processing Record 33 of Set 3 | galich
# Processing Record 34 of Set 3 | santa cruz
# Processing Record 35 of Set 3 | urumqi
# Processing Record 36 of Set 3 | aripuana
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | del rio
# Processing Record 40 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | itarema
# Processing Record 43 of Set 3 | coquimbo
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | novopavlovka
# Processing Record 49 of Set 3 | bandarbeyla
# Processing Record 50 of Set 3 | muli
# Processing Record 1 of Set 4 | kaeo
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | potosi
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | uige
# Processing Record 6 of Set 4 | banepa
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | aasiaat
# Processing Record 9 of Set 4 | katobu
# Processing Record 10 of Set 4 | chipinge
# Processing Record 11 of Set 4 | hirara
# Processing Record 12 of Set 4 | palatka
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | impfondo
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | nalut
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | arica
# Processing Record 20 of Set 4 | baherden
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | korla
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | egvekinot
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | alekseyevsk
# Processing Record 27 of Set 4 | gat
# Processing Record 28 of Set 4 | trofors
# Processing Record 29 of Set 4 | mengyin
# Processing Record 30 of Set 4 | san rafael
# Processing Record 31 of Set 4 | clonakilty
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | panambi
# Processing Record 34 of Set 4 | lompoc
# Processing Record 35 of Set 4 | mamou
# Processing Record 36 of Set 4 | lexington
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | la ronge
# Processing Record 41 of Set 4 | bilma
# Processing Record 42 of Set 4 | perth
# Processing Record 43 of Set 4 | muros
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | conceicao do araguaia
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | talegaon dabhade
# Processing Record 49 of Set 4 | vresina
# Processing Record 50 of Set 4 | ginir
# Processing Record 1 of Set 5 | boundiali
# Processing Record 2 of Set 5 | havre-saint-pierre
# Processing Record 3 of Set 5 | atherton
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | kosh-agach
# Processing Record 6 of Set 5 | migori
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | general roca
# Processing Record 9 of Set 5 | doha
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | northam
# Processing Record 12 of Set 5 | lashio
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | ponta do sol
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | kupang
# Processing Record 18 of Set 5 | zlatoustovsk
# City not found. Skipping...
# Processing Record 19 of Set 5 | conguaco
# Processing Record 20 of Set 5 | silver city
# Processing Record 21 of Set 5 | willowmore
# Processing Record 22 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 5 | umm lajj
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 5 | lumphat
# Processing Record 26 of Set 5 | beyneu
# Processing Record 27 of Set 5 | destin
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | irece
# Processing Record 30 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 5 | moramanga
# Processing Record 32 of Set 5 | teguldet
# Processing Record 33 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 5 | sagaing
# Processing Record 35 of Set 5 | bela
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 5 | delmas
# Processing Record 39 of Set 5 | lahij
# Processing Record 40 of Set 5 | rawson
# Processing Record 41 of Set 5 | funtua
# Processing Record 42 of Set 5 | bahia blanca
# Processing Record 43 of Set 5 | chongoyape
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | candawaga
# City not found. Skipping...
# Processing Record 49 of Set 5 | sri aman
# Processing Record 50 of Set 5 | bowling green
# Processing Record 1 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 6 | ostrovnoy
# Processing Record 3 of Set 6 | kyabe
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | roanoke rapids
# Processing Record 6 of Set 6 | lavrentiya
# Processing Record 7 of Set 6 | meulaboh
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | ahuimanu
# Processing Record 10 of Set 6 | broome
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | komsomolskiy
# Processing Record 13 of Set 6 | kismayo
# Processing Record 14 of Set 6 | concarneau
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | lenger
# Processing Record 19 of Set 6 | scarborough
# Processing Record 20 of Set 6 | manyana
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | tanout
# Processing Record 23 of Set 6 | kachug
# Processing Record 24 of Set 6 | townsville
# Processing Record 25 of Set 6 | gushikawa
# Processing Record 26 of Set 6 | mazyr
# Processing Record 27 of Set 6 | lodwar
# Processing Record 28 of Set 6 | great falls
# Processing Record 29 of Set 6 | fort saint james
# Processing Record 30 of Set 6 | tezu
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | santiago
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | esperance
# Processing Record 35 of Set 6 | beidao
# Processing Record 36 of Set 6 | mingguang
# Processing Record 37 of Set 6 | balikpapan
# Processing Record 38 of Set 6 | loreto
# Processing Record 39 of Set 6 | yulara
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | lazaro cardenas
# Processing Record 42 of Set 6 | yatou
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | westport
# Processing Record 45 of Set 6 | hutchinson
# Processing Record 46 of Set 6 | wladyslawowo
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | at-bashi
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | usolye-sibirskoye
# Processing Record 1 of Set 7 | pareora
# Processing Record 2 of Set 7 | yumen
# Processing Record 3 of Set 7 | nabire
# Processing Record 4 of Set 7 | magaria
# Processing Record 5 of Set 7 | constitucion
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | zhigansk
# Processing Record 8 of Set 7 | viedma
# Processing Record 9 of Set 7 | puerto leguizamo
# Processing Record 10 of Set 7 | orodara
# Processing Record 11 of Set 7 | tiarei
# Processing Record 12 of Set 7 | vao
# Processing Record 13 of Set 7 | malindi
# Processing Record 14 of Set 7 | badiraguato
# Processing Record 15 of Set 7 | bemidji
# Processing Record 16 of Set 7 | sao filipe
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | nadym
# Processing Record 19 of Set 7 | tyukhtet
# Processing Record 20 of Set 7 | nizhniy kuranakh
# Processing Record 21 of Set 7 | kibala
# Processing Record 22 of Set 7 | la troncal
# Processing Record 23 of Set 7 | half moon bay
# Processing Record 24 of Set 7 | port hedland
# Processing Record 25 of Set 7 | husavik
# Processing Record 26 of Set 7 | joshimath
# Processing Record 27 of Set 7 | mount gambier
# Processing Record 28 of Set 7 | sosnovo-ozerskoye
# Processing Record 29 of Set 7 | itacarambi
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | bolivar
# Processing Record 32 of Set 7 | tucuma
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | havoysund
# Processing Record 35 of Set 7 | carutapera
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | poum
# Processing Record 38 of Set 7 | shimoda
# Processing Record 39 of Set 7 | lufilufi
# Processing Record 40 of Set 7 | fort wellington
# Processing Record 41 of Set 7 | severo-kurilsk
# Processing Record 42 of Set 7 | agboville
# Processing Record 43 of Set 7 | praxedis guerrero
# Processing Record 44 of Set 7 | thompson
# Processing Record 45 of Set 7 | lakatoro
# Processing Record 46 of Set 7 | manoel urbano
# Processing Record 47 of Set 7 | morondava
# Processing Record 48 of Set 7 | santa isabel do rio negro
# Processing Record 49 of Set 7 | sorland
# Processing Record 50 of Set 7 | luwuk
# Processing Record 1 of Set 8 | fengkou
# Processing Record 2 of Set 8 | mogadishu
# Processing Record 3 of Set 8 | ekibastuz
# Processing Record 4 of Set 8 | alugan
# Processing Record 5 of Set 8 | lewistown
# Processing Record 6 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 8 | chifeng
# Processing Record 8 of Set 8 | tasiilaq
# Processing Record 9 of Set 8 | yazman
# Processing Record 10 of Set 8 | quatre cocos
# Processing Record 11 of Set 8 | bintulu
# Processing Record 12 of Set 8 | qasigiannguit
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | henties bay
# Processing Record 15 of Set 8 | bonoua
# Processing Record 16 of Set 8 | okhotsk
# Processing Record 17 of Set 8 | lewisporte
# Processing Record 18 of Set 8 | vila franca do campo
# Processing Record 19 of Set 8 | long eaton
# Processing Record 20 of Set 8 | thinadhoo
# Processing Record 21 of Set 8 | xihua
# Processing Record 22 of Set 8 | bonfim
# Processing Record 23 of Set 8 | cururupu
# Processing Record 24 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 8 | belmonte
# Processing Record 26 of Set 8 | zelenoborskiy
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | suoyarvi
# Processing Record 29 of Set 8 | pauini
# Processing Record 30 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 8 | itoman
# Processing Record 32 of Set 8 | almeirim
# Processing Record 33 of Set 8 | alyangula
# Processing Record 34 of Set 8 | pontianak
# Processing Record 35 of Set 8 | tuktoyaktuk
# Processing Record 36 of Set 8 | gremyachye
# City not found. Skipping...
# Processing Record 37 of Set 8 | esna
# Processing Record 38 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 8 | lahaina
# Processing Record 40 of Set 8 | ruteng
# Processing Record 41 of Set 8 | port macquarie
# Processing Record 42 of Set 8 | baracoa
# Processing Record 43 of Set 8 | longyearbyen
# Processing Record 44 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | ayacucho
# Processing Record 47 of Set 8 | san jose
# Processing Record 48 of Set 8 | talcahuano
# Processing Record 49 of Set 8 | abu dhabi
# Processing Record 50 of Set 8 | evensk
# Processing Record 1 of Set 9 | wenling
# Processing Record 2 of Set 9 | jaguaribe
# Processing Record 3 of Set 9 | kartaly
# Processing Record 4 of Set 9 | solnechnyy
# Processing Record 5 of Set 9 | bukama
# Processing Record 6 of Set 9 | brest
# Processing Record 7 of Set 9 | necochea
# Processing Record 8 of Set 9 | dinard
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | lons
# Processing Record 11 of Set 9 | valle de allende
# Processing Record 12 of Set 9 | aros
# Processing Record 13 of Set 9 | mina
# Processing Record 14 of Set 9 | penzance
# Processing Record 15 of Set 9 | cacapava do sul
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | kudahuvadhoo
# Processing Record 18 of Set 9 | muroto
# Processing Record 19 of Set 9 | pontes e lacerda
# Processing Record 20 of Set 9 | ahipara
# Processing Record 21 of Set 9 | goderich
# Processing Record 22 of Set 9 | kemise
# Processing Record 23 of Set 9 | rundu
# Processing Record 24 of Set 9 | iqaluit
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | vanimo
# Processing Record 27 of Set 9 | gurupa
# Processing Record 28 of Set 9 | sibolga
# Processing Record 29 of Set 9 | artigas
# Processing Record 30 of Set 9 | puerto pinasco
# City not found. Skipping...
# Processing Record 31 of Set 9 | the valley
# Processing Record 32 of Set 9 | portachuelo
# Processing Record 33 of Set 9 | ampanihy
# Processing Record 34 of Set 9 | christchurch
# Processing Record 35 of Set 9 | flinders
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | kota belud
# Processing Record 38 of Set 9 | xichang
# Processing Record 39 of Set 9 | rio cuarto
# Processing Record 40 of Set 9 | rovaniemi
# Processing Record 41 of Set 9 | ambon
# Processing Record 42 of Set 9 | kenai
# Processing Record 43 of Set 9 | yanam
# Processing Record 44 of Set 9 | turayf
# Processing Record 45 of Set 9 | guarapari
# Processing Record 46 of Set 9 | sapa
# Processing Record 47 of Set 9 | kahului
# Processing Record 48 of Set 9 | punta alta
# Processing Record 49 of Set 9 | akropong
# Processing Record 50 of Set 9 | sitka
# Processing Record 1 of Set 10 | elizabeth city
# Processing Record 2 of Set 10 | leh
# Processing Record 3 of Set 10 | ugoofaaru
# Processing Record 4 of Set 10 | zeya
# Processing Record 5 of Set 10 | kisesa
# Processing Record 6 of Set 10 | farafangana
# Processing Record 7 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 8 of Set 10 | baiyin
# Processing Record 9 of Set 10 | markova
# Processing Record 10 of Set 10 | kruisfontein
# Processing Record 11 of Set 10 | olinda
# Processing Record 12 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | ust-kuyga
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | saskylakh
# Processing Record 16 of Set 10 | yining
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | hermosillo
# Processing Record 19 of Set 10 | barcelos
# Processing Record 20 of Set 10 | khasan
# Processing Record 21 of Set 10 | maun
# Processing Record 22 of Set 10 | brae
# Processing Record 23 of Set 10 | honiara
# Processing Record 24 of Set 10 | copiapo
# Processing Record 25 of Set 10 | sistranda
# Processing Record 26 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 10 | doka
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | racale
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | weener
# Processing Record 32 of Set 10 | santa fe
# Processing Record 33 of Set 10 | sambava
# Processing Record 34 of Set 10 | lao cai
# Processing Record 35 of Set 10 | dongzhen
# Processing Record 36 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | butembo
# Processing Record 38 of Set 10 | raglan
# Processing Record 39 of Set 10 | moose factory
# Processing Record 40 of Set 10 | kamaishi
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | lieksa
# Processing Record 43 of Set 10 | bambanglipuro
# Processing Record 44 of Set 10 | ilo
# Processing Record 45 of Set 10 | steinbach
# Processing Record 46 of Set 10 | wichita falls
# Processing Record 47 of Set 10 | khonsa
# Processing Record 48 of Set 10 | cidreira
# Processing Record 49 of Set 10 | arman
# Processing Record 50 of Set 10 | houma
# Processing Record 1 of Set 11 | gizo
# Processing Record 2 of Set 11 | riyadh
# Processing Record 3 of Set 11 | severo-yeniseyskiy
# Processing Record 4 of Set 11 | marsh harbour
# Processing Record 5 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 11 | fairbanks
# Processing Record 7 of Set 11 | manicore
# Processing Record 8 of Set 11 | fayaoue
# Processing Record 9 of Set 11 | saint-georges
# Processing Record 10 of Set 11 | kieta
# Processing Record 11 of Set 11 | wanning
# Processing Record 12 of Set 11 | tarko-sale
# Processing Record 13 of Set 11 | abu kamal
# Processing Record 14 of Set 11 | cap malheureux
# Processing Record 15 of Set 11 | manzanillo
# Processing Record 16 of Set 11 | coahuayana
# Processing Record 17 of Set 11 | shenjiamen
# Processing Record 18 of Set 11 | leshukonskoye
# Processing Record 19 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 20 of Set 11 | katangli
# Processing Record 21 of Set 11 | along
# Processing Record 22 of Set 11 | la mana
# Processing Record 23 of Set 11 | maragogi
# Processing Record 24 of Set 11 | dasoguz
# Processing Record 25 of Set 11 | mackay
# Processing Record 26 of Set 11 | fengrun
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | grenville
# Processing Record 29 of Set 11 | waipawa
# Processing Record 30 of Set 11 | banjar
# Processing Record 31 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 11 | sarahan
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | altamont
# Processing Record 35 of Set 11 | porto walter
# Processing Record 36 of Set 11 | sao felix do xingu
# Processing Record 37 of Set 11 | naspur
# Processing Record 38 of Set 11 | petauke
# Processing Record 39 of Set 11 | sangar
# Processing Record 40 of Set 11 | loubomo
# Processing Record 41 of Set 11 | gashua
# Processing Record 42 of Set 11 | sabang
# Processing Record 43 of Set 11 | malanje
# Processing Record 44 of Set 11 | calama
# Processing Record 45 of Set 11 | bundaberg
# Processing Record 46 of Set 11 | nome
# Processing Record 47 of Set 11 | sakakah
# Processing Record 48 of Set 11 | diffa
# Processing Record 49 of Set 11 | ismailia
# Processing Record 50 of Set 11 | sindand
# City not found. Skipping...
# Processing Record 1 of Set 12 | upata
# Processing Record 2 of Set 12 | seoul
# Processing Record 3 of Set 12 | praya
# Processing Record 4 of Set 12 | kayes
# Processing Record 5 of Set 12 | kampot
# Processing Record 6 of Set 12 | himora
# City not found. Skipping...
# Processing Record 7 of Set 12 | sydney
# Processing Record 8 of Set 12 | fare
# Processing Record 9 of Set 12 | ferrol
# Processing Record 10 of Set 12 | moron
# Processing Record 11 of Set 12 | agdas
# Processing Record 12 of Set 12 | gumdag
# Processing Record 13 of Set 12 | suluq
# Processing Record 14 of Set 12 | senanga
# Processing Record 15 of Set 12 | pacific grove
# Processing Record 16 of Set 12 | longonjo
# Processing Record 17 of Set 12 | la palma
# Processing Record 18 of Set 12 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | romanovka
# Processing Record 20 of Set 12 | halmstad
# Processing Record 21 of Set 12 | flin flon
# Processing Record 22 of Set 12 | lima
# Processing Record 23 of Set 12 | walvis bay
# Processing Record 24 of Set 12 | ilulissat
# Processing Record 25 of Set 12 | coatzintla
# Processing Record 26 of Set 12 | dongfeng
# Processing Record 27 of Set 12 | ucluelet
# Processing Record 28 of Set 12 | oksfjord
# Processing Record 29 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 12 | atka
# City not found. Skipping...
# Processing Record 31 of Set 12 | bara
# Processing Record 32 of Set 12 | netarhat
# Processing Record 33 of Set 12 | nantucket
# Processing Record 34 of Set 12 | vizinga
# Processing Record 35 of Set 12 | nuuk
# Processing Record 36 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 12 | kapoeta
# Processing Record 38 of Set 12 | qandala
# Processing Record 39 of Set 12 | rafai
# Processing Record 40 of Set 12 | queimadas
# Processing Record 41 of Set 12 | andenes
# Processing Record 42 of Set 12 | vallenar
# Processing Record 43 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 12 | bac lieu
# Processing Record 45 of Set 12 | sur
# Processing Record 46 of Set 12 | tilichiki
# Processing Record 47 of Set 12 | raga
# Processing Record 48 of Set 12 | vostok
# Processing Record 49 of Set 12 | ust-tarka
# Processing Record 50 of Set 12 | yerbogachen
# Processing Record 1 of Set 13 | fort nelson
# Processing Record 2 of Set 13 | hare bay
# Processing Record 3 of Set 13 | igarka
# Processing Record 4 of Set 13 | casa nova
# Processing Record 5 of Set 13 | cubara
# Processing Record 6 of Set 13 | ereymentau
# Processing Record 7 of Set 13 | ati
# Processing Record 8 of Set 13 | nurota
# Processing Record 9 of Set 13 | taicheng
# Processing Record 10 of Set 13 | berlin
# Processing Record 11 of Set 13 | sabha
# Processing Record 12 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 13 | kaliganj
# Processing Record 14 of Set 13 | suez
# Processing Record 15 of Set 13 | port-gentil
# Processing Record 16 of Set 13 | torrington
# Processing Record 17 of Set 13 | castro-urdiales
# Processing Record 18 of Set 13 | cobija
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | ballitoville
# Processing Record 21 of Set 13 | batagay
# Processing Record 22 of Set 13 | yenagoa
# Processing Record 23 of Set 13 | buala
# Processing Record 24 of Set 13 | clearwater
# Processing Record 25 of Set 13 | ust-nera
# Processing Record 26 of Set 13 | kiama
# Processing Record 27 of Set 13 | lata
# Processing Record 28 of Set 13 | seinajoki
# Processing Record 29 of Set 13 | north bend
# Processing Record 30 of Set 13 | cascais
# Processing Record 31 of Set 13 | kimberley
# Processing Record 32 of Set 13 | casablanca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kralendijk      BQ  12.15  -68.27     82.40        83           1
# 1    Puerto Lumbreras      ES  37.56   -1.81     70.00        48           0
# 2         Belaya Gora      RU  68.53  146.42     50.77        74         100
# 3               Rodeo      US  38.03 -122.27     71.01        49           1
# 4             Ushuaia      AR -54.80  -68.30     35.60        80          22
# ..                ...     ...    ...     ...       ...       ...         ...
# 578         Seinajoki      FI  62.79   22.83     52.00        93          75
# 579        North Bend      US  43.41 -124.22     61.00        77          90
# 580           Cascais      PT  38.70   -9.42     70.00        68           0
# 581         Kimberley      ZA -28.73   24.76     39.20        44           0
# 582        Casablanca      MA  33.59   -7.62     80.01        64           0
#
#      Wind Speed Current Description Rain (inches) Snow (inches)
# 0         13.87           clear sky           0.0           0.0
# 1          1.01           clear sky           0.0           0.0
# 2          9.26     overcast clouds           0.0           0.0
# 3         14.99           clear sky           0.0           0.0
# 4         16.11          few clouds           0.0           0.0
# ..          ...                 ...           ...           ...
# 578        8.05          light rain           0.0           0.0
# 579        5.82     overcast clouds           0.0           0.0
# 580        5.82           clear sky           0.0           0.0
# 581        6.93           clear sky           0.0           0.0
# 582        2.24           clear sky           0.0           0.0
#
# [583 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
