# %%
import pandas as pd
rain_to_load = "avg_rain_state.csv"
cereal_to_load = "cereal.csv"
donors_to_load = "donors2008.csv"

# %%
df = pd.DataFrame({'name': ['Raphael', 'Donatello'],
                   'mask': ['red', 'purple'],
                   'weapon': ['sai', 'bo staff']})
df.to_csv(index=False)
# Out:
# 'name,mask,weapon\r\nRaphael,red,sai\r\nDonatello,purple,bo staff\r\n'

# %%
import os
import csv

file_to_save = os.path.join("output", "employees")

with open("file_to_save", "w") as new_file:
    employees = (
        f"First Name', 'Last Name', 'SSN\n"
        f"Caleb', 'Frost', '505-80-2901\n")

    new_file.write(employees)

print(employees)
# Out:
# First Name', 'Last Name', 'SSN
# Caleb', 'Frost', '505-80-2901

# %%
import os
import csv

file_to_save = os.path.join("output","employees.txt")

print(file_to_save)
# Out:
# output\employees.txt

# %%
import pandas as pd

test_grades = {
    'Class': ['Oct', 'Oct', 'Jan', 'Jan', 'Oct', 'Jan'], 
    'Name': ["Cyndy", "Logan", "Laci", "Elmer", "Crystle", "Emmie"], 
    'Test Score': [90, 59, 72, 88, 98, 60]}

# %%
test_grades['Letter Grade'] = pd.cut(test_grades['Test Score'], bins, labels=[letter_grades])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9f735c56b3d5> in <module>
# ----> 1 test_grades['Letter Grade'] = pd.cut(test_grades['Test Score'], bins, labels=[letter_grades])
#
# NameError: name 'bins' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(rain_to_load)
df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# ...

# %%
tick_locations = [value for value in df['State']]
plt.figure(figsize=(20,3))
plt.bar(df['State'],df['Inches'])
plt.xticks(tick_locations, df['State'], rotation='vertical')
plt.title("Rain in Inches by State")
plt.xlabel("State")
plt.ylabel("Rain (inches)")
# Out:
# Text(0, 0.5, 'Rain (inches)')

# %%
DonorsDF = pd.read_csv(donors_to_load)
DonorsDF
# Out:
#         LastName FirstName          Employer           City State    Zip  \
# 0          Aaron    Eugene  State Department         Dulles    VA  20189
# 1          Abadi   Barbara       Abadi & Co.       New York    NY  10021
# 2        Adamany   Anthony           Retired       Rockford    IL  61103
# 3          Adams  Lorraine              Self       New York    NY  10026
# 4          Adams    Marion              None         Exeter    NH  03833
# ...          ...       ...               ...            ...   ...    ...
# 1771   Zinczenko     David            Rodale      Allentown    PA  18102
# 1772  Zschiesche     Peter               NaN      San Diego    CA  92104
# 1773  Zweidinger      Ruth               NaN   Hillsborough    NC  27278
# 1774   Zwerdling     David    Montg Cnty, Md  Silver Spring    MD  20910
# 1775     Zyskind       Jon      JDS Uniphase        Concord    MA  10742
#
#       Amount  FIELD8
# 0      500.0     NaN
# 1      200.0     NaN
# 2      500.0     NaN
# ...

# %%
DonorsDF.columns
# Out:
# Index(['LastName', 'FirstName', 'Employer', 'City', 'State', 'Zip', 'Amount',
#        'FIELD8'],
#       dtype='object')

# %%
CityAvg = DonorsDF.groupby(['State']).mean()['Amount']
CityAvg
# Out:
# State
# AE     100.000000
# AK     175.000000
# AL     212.500000
# AP     200.000000
# AR     350.000000
# AZ     206.000000
# CA     685.234973
# CO     851.250000
# CT     825.714286
# DC     647.115385
# DE     190.000000
# FL     709.358974
# GA     842.307692
# HI     195.454545
# IA     600.000000
# ID     341.666667
# IL    1114.519231
# IN     225.000000
# KS     283.333333
# KY     735.000000
# LA     158.333333
# MA     750.714286
# MD     819.823529
# ME     211.111111
# MI     241.666667
# MN     697.000000
# MO     463.888889
# MS    1208.333333
# MT     200.000000
# NC     440.625000
# NE     183.333333
# NH     368.750000
# NJ     276.111111
# NM     298.913043
# NV     393.333333
# NY     910.829146
# OH     501.562500
# OK     200.000000
# OR     321.052632
# PA     896.755556
# QC     250.000000
# RI     700.000000
# SC     287.500000
# TN     257.142857
# TX     485.193182
# UT     200.000000
# VA     701.093465
# VI     225.000000
# VT     350.000000
# ...

# %%
# type(CityAvg)
CityAvgDF = pd.DataFrame(CityAvg)
# type(CityAvg)
CityAvgDF
# Out:
#             Amount
# State
# AE      100.000000
# AK      175.000000
# AL      212.500000
# AP      200.000000
# AR      350.000000
# AZ      206.000000
# CA      685.234973
# CO      851.250000
# CT      825.714286
# DC      647.115385
# DE      190.000000
# FL      709.358974
# GA      842.307692
# HI      195.454545
# IA      600.000000
# ID      341.666667
# IL     1114.519231
# IN      225.000000
# KS      283.333333
# KY      735.000000
# LA      158.333333
# MA      750.714286
# MD      819.823529
# ME      211.111111
# MI      241.666667
# MN      697.000000
# MO      463.888889
# MS     1208.333333
# MT      200.000000
# NC      440.625000
# NE      183.333333
# NH      368.750000
# NJ      276.111111
# NM      298.913043
# NV      393.333333
# NY      910.829146
# OH      501.562500
# OK      200.000000
# OR      321.052632
# PA      896.755556
# QC      250.000000
# RI      700.000000
# SC      287.500000
# TN      257.142857
# TX      485.193182
# UT      200.000000
# ...

# %%
Total = CityAvgDF[CityAvgDF['Amount'] >= 750.0].count()
Total
# Out:
# Amount    9
# dtype: int64

# %%
import os
import csv
cereal_csv = "cereal.csv"

# %%
with open(cereal_csv, newline="") as csvfile:
    csvreader = csv.reader(cereal_csv, delimiter=",")

# %%
print(cereal_csv)
# Out:
# cereal.csv

# %%
with open(cereal_csv, newline="") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")

    csv_header = next(csvfile)

    for row in csvreader:
        if float(row[7]) >= 5:
            print(row[0])
# Out:
# 100% Bran
# All-Bran
# All-Bran with Extra Fiber
# Bran Flakes
# Fruit & Fibre Dates; Walnuts; and Oats
# Fruitful Bran
# Post Nat. Raisin Bran
# Raisin Bran

# %%
# Dictionary with three keys 
Dictionary1 = {'A': 'Geeks', 'B': 'For', 'C': 'Geeks'} 
  
# Printing keys of dictionary 
Dictionary1.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
import json
import os

filepath = os.path.join("youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
video_json['data']['items'][0]['thumbnail']['hqDefault']
# Out:
# 'http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg'

# %%
try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except ZeroDivisionError:
    try:
        print("I think her name was + " + name + "?")
    except NameError:
        try:
            print("Your name is a nonsense number. Look: " + int("Gabriel"))
        except ValueError:
            print("I made it through the gauntlet. The message survived!")
# Out:
# I made it through the gauntlet. The message survived!

# %%
pies = ["Apple", "Pumpkin", "Chocolate Creme", "Cherry", "Apple Crumb", "Pecan", "Lemon Meringue", "Blueberry", "Key Lime", "Peach"]
pie_votes = [47,37,32,27,25,24,24,21,18,16]
colors = ["yellow","green","lightblue","orange","red","purple","pink","yellowgreen","lightskyblue","lightcoral"]
offset = (0,0,0,0.2,0,0,0,0,0,0)

# %%
pie_votes[3] / sum(pie_votes) * 100
# Out:
# 9.96309963099631

# %%
students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
students.append("Serena")
print(students)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-72be960c98fd> in <module>
#       1 students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
# ----> 2 students.append("Serena")
#       3 print(students)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
import requests
url = "https://api.spacexdata.com/v2/launchpads"

print(url)
# Out:
# https://api.spacexdata.com/v2/launchpads

# %%
import json
import os

spaceX = requests.get(url)

spaceX.json()
# Out:
# [{'padid': 5,
#   'id': 'vafb_slc_3w',
#   'name': 'VAFB SLC 3W',
#   'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W',
#   'status': 'retired',
#   'location': {'name': 'Vandenberg Air Force Base',
#    'region': 'California',
#    'latitude': 34.6440904,
#    'longitude': -120.5931438},
#   'vehicles_launched': ['Falcon 1'],
#   'attempted_launches': 0,
#   'successful_launches': 0,
#   'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3',
#   'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'},
#  {'padid': 2,
#   'id': 'ccafs_slc_40',
#   'name': 'CCAFS SLC 40',
#   'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40',
#   'status': 'active',
#   'location': {'name': 'Cape Canaveral',
#    'region': 'Florida',
#    'latitude': 28.5618571,
#    'longitude': -80.577366},
# ...

# %%
len(spaceX)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-5f1c64284cb3> in <module>
# ----> 1 len(spaceX)
#
# TypeError: object of type 'Response' has no len()

# %%
spaceX_file = spaceX.json()
spaceX_file[0]['full_name']
# Out:
# 'Vandenberg Air Force Base Space Launch Complex 3W'

# %%
for full in spaceX[0]['full_name']:
    print(full)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-f2f71f8a3473> in <module>
# ----> 1 for full in spaceX[0]['full_name']:
#       2     print(full)
#
# TypeError: 'Response' object is not subscriptable

# %%
for full in spaceX_file:
    spaceX_file[0]['full_name']
    print(full)
# Out:
# {'padid': 5, 'id': 'vafb_slc_3w', 'name': 'VAFB SLC 3W', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W', 'status': 'retired', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3', 'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'}
# ...

# %%
x = 0
for full in spaceX_file:
    print(spaceX_file[x]['full_name'])
    x += 1
# Out:
# Vandenberg Air Force Base Space Launch Complex 3W
# Cape Canaveral Air Force Station Space Launch Complex 40
# SpaceX South Texas Launch Site
# Kwajalein Atoll Omelek Island
# Vandenberg Air Force Base Space Launch Complex 4E
# Kennedy Space Center Historic Launch Complex 39A

# %%
rainDF = pd.read_csv(rain_to_load)
rainDF.describe()
# Out:
#           Inches  Milli­metres       Rank
# count  50.000000     50.000000  50.000000
# mean   37.078000    941.820000  25.480000
# std    14.635898    371.752095  14.599748
# min     9.500000    241.000000   1.000000
# 25%    24.525000    622.500000  13.250000
# 50%    41.750000   1061.000000  25.500000
# 75%    47.850000   1216.250000  37.750000
# max    63.700000   1618.000000  50.000000

# %%
rainDF.median()
# Out:
# Inches            41.75
# Milli­metres    1061.00
# Rank              25.50
# dtype: float64

# %%
rainDF.mode()
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    28.9        1279.0   9.0
# 1           Alaska    42.2           NaN   NaN
# 2          Arizona    50.3           NaN   NaN
# 3         Arkansas     NaN           NaN   NaN
# 4       California     NaN           NaN   NaN
# 5         Colorado     NaN           NaN   NaN
# 6      Connecticut     NaN           NaN   NaN
# 7         Delaware     NaN           NaN   NaN
# 8          Florida     NaN           NaN   NaN
# 9          Georgia     NaN           NaN   NaN
# 10          Hawaii     NaN           NaN   NaN
# 11           Idaho     NaN           NaN   NaN
# 12        Illinois     NaN           NaN   NaN
# 13         Indiana     NaN           NaN   NaN
# 14            Iowa     NaN           NaN   NaN
# 15          Kansas     NaN           NaN   NaN
# 16        Kentucky     NaN           NaN   NaN
# 17       Louisiana     NaN           NaN   NaN
# 18           Maine     NaN           NaN   NaN
# ...
